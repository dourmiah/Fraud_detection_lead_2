# %%
import pandas as pd
import glob

# %%
filepath = glob.glob("../data/data-drift/*.csv")
filepath
# Out:
# ['../data/data-drift\\fraudTest-sample-drift-2.csv',
#  '../data/data-drift\\fraudTest-sample-drifted.csv']

# %%
data_logs_list = glob.glob("../data/data-drift/*.csv")
data_logs_list
# Out:
# ['../data/data-drift\\fraudTest-sample-drift-2.csv',
#  '../data/data-drift\\fraudTest-sample-drifted.csv']

# %%
reference = pd.read_csv("../data/reference/fraudTest-sample.csv")
reference.head()

# %%
reference = reference.drop(labels="trans_date_trans_time", axis=1) # We do not need datetime column
reference.head()
# Out:
#    Unnamed: 0            cc_num                              merchant  \
# 0           0  2291163933867240                 fraud_Kirlin and Sons
# 1           1  3573030041201290                  fraud_Sporer-Keebler
# 2           2  3598215285024750  fraud_Swaniawski, Nitzsche and Welch
# 3           3  3591919803438420                     fraud_Haley Group
# 4           4  3526826139003050                 fraud_Johnston-Casper
#
#          category    amt   first      last gender  \
# 0   personal_care   2.86    Jeff   Elliott      M
# 1   personal_care  29.84  Joanne  Williams      F
# 2  health_fitness  41.28  Ashley     Lopez      F
# 3        misc_pos  60.05   Brian  Williams      M
# 4          travel   3.19  Nathan    Massey      M
#
#                         street        city  ...      lat      long  city_pop  \
# 0            351 Darlene Green    Columbia  ...  33.9659  -80.9355    333497
# 1             3638 Marsh Union     Altonah  ...  40.3207 -110.4360       302
# ...

# %%
reference = reference.select_dtypes(include="number") # We keep only numbers
reference.head()
# Out:
#    Unnamed: 0            cc_num    amt    zip      lat      long  city_pop  \
# 0           0  2291163933867240   2.86  29209  33.9659  -80.9355    333497
# 1           1  3573030041201290  29.84  84002  40.3207 -110.4360       302
# 2           2  3598215285024750  41.28  11710  40.6729  -73.5365     34496
# 3           3  3591919803438420  60.05  32780  28.5697  -80.8191     54767
# 4           4  3526826139003050   3.19  49632  44.2529  -85.0170      1126
#
#     unix_time  merch_lat  merch_long  is_fraud
# 0  1371816865  33.986391  -81.200714         0
# 1  1371816873  39.450498 -109.960431         0
# 2  1371816893  40.495810  -74.196111         0
# 3  1371816915  28.812398  -80.883061         0
# 4  1371816917  44.959148  -85.884734         0

# %%
reference = reference.drop(labels="trans_date_trans_time", axis=1) # We do not need datetime column
reference = reference.select_dtypes(include="number") # We keep only numbers

# %%
def _detect_file():
    data_logs_list = glob.glob("../data/data-drift/*.csv")
    print(f"Files detected: {data_logs_list}")
    if not data_logs_list:
        print("No files found.")
        return False
    data_logs_filename = max(data_logs_list, key=os.path.getctime)
    print(f"Selected file: {data_logs_filename}")
    return True

print(_detect_file())

# %%
def _detect_file():
    """Detects if a file named `*.csv` is inside `./data/data-drift` folder.

    If yes, it saves the full path to XCom and return True. False otherwise.
    """
    data_logs_list = glob.glob("../data/data-drift/*.csv")
    if not data_logs_list:
        return False
    data_logs_filename = max(data_logs_list, key=os.path.getctime)
    print(f"Selected file: {data_logs_filename}")
    return True

print(_detect_file())
# Out:
# Selected file: ../data/data-drift\fraudTest-sample-drifted.csv
# True
